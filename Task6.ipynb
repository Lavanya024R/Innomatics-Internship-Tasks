# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavanya024R/Innomatics-Internship-Tasks/blob/main/Task6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1: Smart Parking Lot Management System

# %%
def smart_parking(capacity, logs):
    current = 0
    peak = 0

    for log in logs:
        if log == "IN":
            current += 1
        elif log == "OUT" and current > 0:
            current -= 1

        if current > peak:
            peak = current

    print("Currently Parked Vehicles:", current)

    if current > capacity:
        print("Parking Status: Full - Alert!")
    else:
        print("Parking Status: Available")

    print("Peak Usage:", peak)

# %%
smart_parking(50, ["IN", "IN", "IN", "OUT", "IN", "IN", "OUT"])
# Out:
# Currently Parked Vehicles: 3
# Parking Status: Available
# Peak Usage: 4

# %%
def estimate_delivery(distance, traffic, weather):
    base_time = distance * 5   # 5 minutes per km

    # Traffic adjustment
    if traffic == "High":
        base_time += 15
    elif traffic == "Medium":
        base_time += 8

    # Weather adjustment
    if weather == "Rainy":
        base_time += 10
    elif weather == "Storm":
        base_time += 20

    print("Estimated Delivery Time:", base_time, "minutes")

# %%
estimate_delivery(8, "High", "Rainy")
# Out:
# Estimated Delivery Time: 65 minutes

# %%
def seat_occupancy(total_seats, booked_seats):
    booked = len(booked_seats)
    occupancy = (booked / total_seats) * 100

    print("Occupancy:", int(occupancy), "%")

    if occupancy == 100:
        print("Show Status: Housefull")
    elif occupancy >= 75:
        print("Show Status: Almost Full")
    else:
        print("Show Status: Seats Available")

# %%
seat_occupancy(200, [1]*150)
# Out:
# Occupancy: 75 %
# Show Status: Almost Full

# %%
def server_load(cpu_readings):
    total = 0

    for cpu in cpu_readings:
        total += cpu

    average = total / len(cpu_readings)

    print("Average CPU Load:", int(average), "%")

    if average < 50:
        print("Server Status: Normal")
    elif 50 <= average <= 80:
        print("Server Status: Warning")
    else:
        print("Server Status: Critical")

# %%
server_load([45, 60, 70, 85, 90])
# Out:
# Average CPU Load: 70 %
# Server Status: Warning

# %%
def resource_monitor(resources):
    overused = []

    for resource, hours in resources.items():
        if hours > 8:
            overused.append(resource)

    if overused:
        print("Overused Resources:", ", ".join(overused))
        print("Energy Alert: Yes")
    else:
        print("Overused Resources: None")
        print("Energy Alert: No")

# %%
usage = {
    "Projector": 6,
    "AC": 9,
    "Lights": 4
}

resource_monitor(usage)
# Out:
# Overused Resources: AC
# Energy Alert: Yes
